# %%
presure = 95
if presure >= 90 and presure <= 120:
    print("正常")
else:
    print("不正常")

presure = int(input("Enter your blood pressure"))
if not(presure < 90 or presure > 120):
    print("正常")
else:
    print("不正常")
# Out:
# 正常
# 不正常
