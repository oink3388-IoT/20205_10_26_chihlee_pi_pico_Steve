# %%
print ("Hello Python!")
# Out:
# Hello Python!

# %%
a = 10
b = 3
print(a + b)   # 13
print(a / b)   # 3.333...（浮點數除法）
print(a // b)  # 3     （整數除法，取商）
print(a % b)   # 1     （取餘數）
print(a ** b)  # 1000  （次方）
# Out:
# 13
# 3.3333333333333335
# 3
# 1
# 1000

# %%
n1 = 5 + 10
n2 = 20 - 15
n1
n2
# Out:
# 5

# %%
print(10)
print(20 + 10)
# Out:
# 10
# 30

# %%
a
b
# Out:
# 3

# %%
m1=5
m2=5.0
m3='5.0'
m4="5.0"
m5=True
print(type(m1))
print(type(m2))
print(type(m3))
print(type(m4))
print(type(m5))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
